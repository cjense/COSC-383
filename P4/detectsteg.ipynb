# %%
import detect_steg as ds
import os

# %% [markdown]
# ### Magnify Image's LSB

# %%
for file in os.listdir('PNGs'):
    ds.grab_magnified('PNGs/' + file, 'magnified/' + file)

# %% [markdown]
# ### Produce Histogram

# %%
for file in os.listdir('PNGs'):
    ds.grab_hist('PNGs/' + file, 'histograms/' + file)
# Out:
# c:\Users\clair\Desktop\Coding\COSC-383\P4\utils.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 1)  # Get container for returning plot
